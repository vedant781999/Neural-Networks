# %% [markdown]
# #Neural Networks

# %% [markdown]
# # Mount Drive

# %%
# from google.colab import drive
# drive.mount('/drive')

# %% [markdown]
# #Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
from sklearn.preprocessing import OneHotEncoder
import math
from sklearn.model_selection import train_test_split

# %%
# DATASET 
#data = pd.read_csv('/drive/My Drive/Colab Notebooks/housepricedata.csv')
data = pd.read_csv("/content/housepricedata.csv")

# %%
data
# Out:
#       LotArea  OverallQual  ...  GarageArea  AboveMedianPrice
# 0        8450            7  ...         548                 1
# 1        9600            6  ...         460                 1
# 2       11250            7  ...         608                 1
# 3        9550            7  ...         642                 0
# 4       14260            8  ...         836                 1
# ...       ...          ...  ...         ...               ...
# 1455     7917            6  ...         460                 1
# 1456    13175            6  ...         500                 1
# 1457     9042            7  ...         252                 1
# 1458     9717            5  ...         240                 0
# 1459     9937            5  ...         276                 0
#
# [1460 rows x 11 columns]

# %%
X = data.drop('AboveMedianPrice',axis = 1)
Y = data['AboveMedianPrice']

# %% [markdown]
# ## Train-Test Split

# %%
X_train, X_test, Y_train_not_encoded, Y_test_not_encoded = train_test_split(X, Y, test_size=0.2, random_state=1,stratify = Y)

# %%
# PANDAS DATAFRAMES TO NUMPY ARRAYS
X_train = X_train.values
Y_train_not_encoded = Y_train_not_encoded.values
X_test = X_test.values
Y_test_not_encoded = Y_test_not_encoded.values

# %% [markdown]
# ## One hot encoding of Test Data

# %%
enc = OneHotEncoder()
# 0 -> (1, 0, 0, 0), 1 -> (0, 1, 0, 0), 2 -> (0, 0, 1, 0), 3 -> (0, 0, 0, 1)
Y_train = enc.fit_transform(np.expand_dims(Y_train_not_encoded,1)).toarray()
Y_test = enc.fit_transform(np.expand_dims(Y_test_not_encoded,1)).toarray()

# %% [markdown]
# ## Standardization

# %%
mean_train=[X_train[:,0].mean(),X_train[:,1].mean(),X_train[:,2].mean(),X_train[:,3].mean(),X_train[:,4].mean(),X_train[:,5].mean(),X_train[:,6].mean(),X_train[:,7].mean(),X_train[:,8].mean(),X_train[:,9].mean()]
std_train=[X_train[:,0].std(),X_train[:,1].std(),X_train[:,2].std(),X_train[:,3].std(),X_train[:,4].std(),X_train[:,5].std(),X_train[:,6].std(),X_train[:,7].std(),X_train[:,8].std(),X_train[:,9].std()]

# %%
for x in range(X_train.shape[0]):
  X_train[x] = (X_train[x] - mean_train)/std_train

for x in range(X_test.shape[0]):
  X_test[x] = (X_test[x] - mean_train)/std_train

# %% [markdown]
# # Training of Model Starts

# %% [markdown]
# ## Activation Functions

# %%
def sigmoid(x):
  return 1/(1+np.exp(-x))

def softmax(x,y):
  return np.exp(x)/(np.exp(x)+np.exp(y))

def tanh(x):
  return 2*(sigmoid(2*x)) - 1

# %% [markdown]
# ## Number of Hidden Neurons

# %%
hidden_neurons = 25                                                #################################

# %% [markdown]
# ## Weights Initialization

# %%
# wts1 = np.random.uniform(0,1,(hidden_neurons,X_train.shape[1]))    #################################
# b1 = np.random.uniform(0,1,hidden_neurons)                         #################################

# wts2 = np.random.uniform(0,1,(2,hidden_neurons))                   #################################
# b2 = np.random.uniform(0,1,2)                                      #################################
# wt_text="Uniform"                                                 #################################

# %%
wts1 = np.random.randn(hidden_neurons,X_train.shape[1])          #################################
b1 = np.random.randn(hidden_neurons)                             #################################

wts2 = np.random.randn(2,hidden_neurons)                         #################################
b2 = np.random.randn(2)                                          #################################
wt_text="Gaussian"                                               #################################

# %%
pred_value = np.zeros((X_train.shape[0],2))
lr = 0.0005                                                        #################################
epochs = 350                                                       #################################
activation_text="Sigmoid"                                    ################################
#activation_text="tanh"                                       ################################

# %% [markdown]
# ## Feed Forward and Backpropagation

# %%
# Gradient Descent

loss = []
for epoch in tqdm_notebook(range(epochs),total = epochs, unit = 'epoch'):
  error = 0
  a1 = np.dot(X_train,wts1.T)
  for i in range(a1.shape[0]):
    for j in range(a1.shape[1]):
      a1[i][j]+=b1[j]

  h1 = np.zeros(a1.shape)
  for i in range(a1.shape[0]):
    for j in range(a1.shape[1]):
        h1[i][j] = sigmoid(a1[i][j])                                #################################

  a2 = np.dot(h1,wts2.T)
  for i in range(a2.shape[0]):
    for j in range(a2.shape[1]):
      a2[i][j]+=b2[j]


  for i in range(a2.shape[0]):
    pred_value[i][0] = softmax(a2[i][0],a2[i][1])
    pred_value[i][1] = softmax(a2[i][1],a2[i][0])

  for i in range(len(pred_value)):
    if Y_train[i][0] == 1:
      error+=np.log(pred_value[i][0])
    else:
      error+=np.log(pred_value[i][1])
  error*=-1
  error/=X_train.shape[0]
  loss.append(error)

# Backpropagation

  grad_w2 = np.zeros((hidden_neurons,2))
  grad_b2 = np.zeros((1,2))
  
  grad_w1 = np.zeros((X_train.shape[1],hidden_neurons))
  grad_b1 = np.zeros((1,hidden_neurons))

  grad_a2 = pred_value - Y_train

  grad_w2 = np.dot(grad_a2.T, h1)
  grad_b2 = np.sum(grad_a2,axis = 0)
  grad_h1 = np.dot(grad_a2,wts2)
  grad_a1 = np.multiply(grad_h1,np.multiply(h1,1-h1))              #################################
  #grad_a1 = np.multiply(grad_h1,1 - np.multiply(h1,h1))           #################################
  
  grad_w1 = np.dot(grad_a1.T,X_train)
  grad_b1 = np.sum(grad_a1,axis = 0) 

  #Update Rule
  wts2 = wts2 - lr*grad_w2
  b2 = b2 - lr*grad_b2
  wts1 = wts1 - lr*grad_w1
  b1 = b1 - lr*grad_b1
  print(error)                                                   #################################
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# HBox(children=(IntProgress(value=0, max=350), HTML(value='')))
# 2.104913441604239
# 0.9805942531781204
# 0.8675116457693176
# 0.784040138716871
# 0.7224719300605846
# 0.6722502105625018
# 0.6325696710286047
# 0.5989543103651788
# 0.5714506711087878
# 0.5481025946036455
# 0.528478547255021
# 0.5116164486229969
# 0.49700806715235973
# 0.4841510825381541
# 0.47271410147303694
# 0.4624399060539358
# 0.45314583888803833
# 0.44469216625288316
# 0.4369707978982881
# 0.42989387303004356
# 0.4233884259993073
# 0.4173924393137451
# 0.41185260841088556
# 0.40672269320666515
# 0.40196234991738894
# 0.3975362061435776
# 0.39341312141325324
# 0.38956557786054413
# 0.38596917386313934
# 0.38260219970030757
# 0.3794452800812713
# 0.3764810717071149
# 0.2919415940073862
# 0.29186945201219955
# 0.2917974979792823
# 0.29172573095085746
# 0.2916541499238747
# 0.29158275385228405
# 0.29151154164940074
# 0.29144051219039824
# 0.29136966431485123
# 0.2912989968293469
# 0.2912285085101048
# 0.29115819810562277
# 0.29108806433929
# 0.2910181059119934
# 0.2909483215046696
# 0.29087870978080693
# 0.2908092693888968
# 0.29073999896477626
# 0.29067089713394034
# 0.29060196251372555
# 0.2905331937154307
# 0.2904645893463354
# 0.2903961480116216
# 0.29032786831620205
# 0.2902597488664588
# 0.2901917882718752
# 0.2901239851465852
# 0.2900563381108213
# 0.28998884579228235
# 0.289921506827398
# 0.2898543198625361
# 0.28978728355509653
# 0.28972039657455295
# 0.2896536576034072
# 0.28958706533807166
# 0.28952061848969457
# 0.28945431578490755
# 0.28938815596652023

# %% [markdown]
# ## Loss vs Epochs

# %%
fig_text="Weight initialization- "+ wt_text + "\nActivation function- "+ activation_text + "\nHidden neurons- " + str(hidden_neurons)+ "\nEpochs="+ str(epochs)+"\nLearning Rate="+str(lr)
print(fig_text)
# Out:
# Weight initialization- Gaussian
# Activation function- Sigmoid
# Hidden neurons- 25
# Epochs=350
# Learning Rate=0.0005

# %%
plt.plot(loss)                       ###########################################
plt.text(150, 0.45, fig_text)        ###########################################
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# #Evaluation

# %%
pred_value = np.zeros((X_test.shape[0],2))
a1 = np.dot(X_test,wts1.T)
for i in range(a1.shape[0]):
  for j in range(a1.shape[1]):
    a1[i][j]+=b1[j]

h1 = np.zeros(a1.shape)
for i in range(a1.shape[0]):
  for j in range(a1.shape[1]):
      h1[i][j] = sigmoid(a1[i][j])                   ###################################

a2 = np.dot(h1,wts2.T)
for i in range(a2.shape[0]):
  for j in range(a2.shape[1]):
    a2[i][j]+=b2[j]


for i in range(a2.shape[0]):
  pred_value[i][0] = softmax(a2[i][0],a2[i][1])
  pred_value[i][1] = softmax(a2[i][1],a2[i][0])

for i in range(len(pred_value)):
  if Y_test[i][0] == 1:
    error+=np.log(pred_value[i][0])
  else:
    error+=np.log(pred_value[i][1])
error*=-1
error/=X_test.shape[0]
loss.append(error)

# %%
pred_y = []

# %%
for i in range(len(pred_value)):
  if pred_value[i][0]>pred_value[i][1]:
    pred_y.append(0)
  else:
    pred_y.append(1)

# %%
tp=0 #true positive
tn=0 #true negative
fp=0 #false positive
fn=0 #false negative
for i in range(len(Y_test)):
  if Y_test_not_encoded[i] == pred_y[i] ==1:
    tp+=1
  elif Y_test_not_encoded[i] == pred_y[i] ==0:
    tn+=1
  elif pred_y[i]==1 and Y_test_not_encoded[i]==0:
    fp+=1
  elif Y_test_not_encoded[i]==1 and pred_y[i]==0:
    fn+=1

# %%
test_accuracy = (tp+tn)/(tp+tn+fp+fn)
print(test_accuracy)
# Out:
# 0.8595890410958904

# %%
precision = tp/(tp+fp)
recall = tp/(tp+fn)
precision
# Out:
# 0.847682119205298

# %%
recall
# Out:
# 0.8767123287671232

# %%
f_score = 2*precision*recall/(precision+recall)
f_score
# Out:
# 0.861952861952862
